# %%
##Basic Syntax rules
##Case sensitivity

name="hdjkk"
Name="kchjdhb"

print(name)
print(Name)
# Out:
# hdjkk
# kchjdhb

# %%
##Indentation
age=32
if age>30:
    print(age)
print(age)
# Out:
# 32
# 32
